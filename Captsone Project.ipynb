# %% [markdown]
# Capstone Project

# %% [markdown]
# The Capstone Project will be centered around the Battle of Neighborhoods. The intention- to manipulate data through coding, use of data location
# to answer specific  research questions.

# %%
import numpy as np
import pandas as pd

# %%
print  ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
